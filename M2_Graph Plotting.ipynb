# %%
import matplotlib.pyplot as plt
import pandas
Raw_housing_data=pandas.read_csv("1. Regression - Module - (Housing Prices).csv")

# %%
plt.plot(Raw_housing_data['Sale Price']) #Plotting line graph

# %%
plt.plot(Raw_housing_data['Sale Price'], color='red') #Plotting line graph with color
plt.xlabel("Record Number")
plt.ylabel("Sale Price")
plt.title("My First Graph")
plt.show()

# %%
plt.plot(Raw_housing_data['Sale Price'], marker='o', markerfacecolor='black', markersize=5, color='red', linewidth=5, linestyle='dashed')

# %%
Raw_housing_data.groupby("Condition of the House")['ID'].count()
# Out:
# Condition of the House
# Bad             30
# Excellent     1701
# Fair         14031
# Good          5679
# Okay           172
# Name: ID, dtype: int64

# %%
values=(30,1701,14031,5679,172)
labels=('Bad','Excellent','Fair','Good','Okay')

# %%
plt.pie(values,labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x2c0418bccd0>,
#   <matplotlib.patches.Wedge at 0x2c0477a24d0>,
#   <matplotlib.patches.Wedge at 0x2c047791510>,
#   <matplotlib.patches.Wedge at 0x2c0477b41d0>,
#   <matplotlib.patches.Wedge at 0x2c0477b5190>],
#  [Text(1.099989541385049, 0.004796753434368107, 'Bad'),
#   Text(1.0641591373844368, 0.27850553014475643, 'Excellent'),
#   Text(-0.9085709380486652, 0.620079713047741, 'Fair'),
#   Text(0.7046888223897579, -0.8446381850229934, 'Good'),
#   Text(1.0996562341282203, -0.02749848619362501, 'Okay')])

# %%
plt.bar(labels,values,color='blue')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(labels,values,color='blue',linewidth=5,linestyle='dashed')
plt.xlabel("Condition of the house")
plt.ylabel("Count")
plt.title("My First Graph")
plt.show()

# %%
plt.scatter(x=Raw_housing_data["Flat Area (in Sqft)"], y=Raw_housing_data['Sale Price'], color='red')
plt.xlabel("Area")
plt.ylabel("Selling Price")
plt.title("Selling Price vs Area")
plt.show()

# %%
plt.hist(Raw_housing_data['Age of House (in Years)'], bins=10)
# Out:
# (array([3592., 2663., 2784., 2525., 3218., 2587., 1361., 1079.,  952.,
#          852.]),
#  array([  3. ,  14.5,  26. ,  37.5,  49. ,  60.5,  72. ,  83.5,  95. ,
#         106.5, 118. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(Raw_housing_data['Age of House (in Years)'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2c047f59110>,
#   <matplotlib.lines.Line2D at 0x2c047f59190>],
#  'caps': [<matplotlib.lines.Line2D at 0x2c047f5a650>,
#   <matplotlib.lines.Line2D at 0x2c047f9e4d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2c048011610>],
#  'medians': [<matplotlib.lines.Line2D at 0x2c047f9ead0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2c0480dd950>],
#  'means': []}
